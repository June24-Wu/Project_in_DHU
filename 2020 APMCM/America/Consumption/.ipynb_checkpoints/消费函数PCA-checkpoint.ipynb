# %%
import tushare as ts
import pandas as pd 
import numpy as np

# %%
data = pd.read_csv('消费者股票指数.csv')
data.set_index('trade_date',inplace=True)
data
# Out:
#                KO      PG     PEP     WMT     PM
# trade_date
# 2015/1/2    42.14   90.44   94.44   85.90  81.02
# 2015/1/5    42.14   90.01   93.73   85.65  80.41
# 2015/1/6    42.46   89.60   93.02   86.31  81.10
# 2015/1/7    42.99   90.07   95.74   88.60  81.71
# 2015/1/8    43.51   91.10   97.48   90.47  82.94
# ...           ...     ...     ...     ...    ...
# 2020/11/19  53.13  139.53  143.32  152.12  77.51
# 2020/11/20  52.67  139.30  143.42  150.24  76.73
# 2020/11/23  52.68  138.76  143.02  150.93  76.63
# 2020/11/24  53.22  138.31  144.03  151.36  78.02
# 2020/11/25  52.93  138.68  144.16  151.83  76.89
#
# [1485 rows x 5 columns]

# %%
from sklearn.feature_selection import VarianceThreshold  # sklearn 方差过滤API
from sklearn.decomposition import PCA  # 主成分分析
from sklearn.impute import SimpleImputer # 处理缺失值


var = VarianceThreshold(threshold=1)  # threshold 是门槛
var_data = var.fit_transform(data)
var_data = pd.DataFrame(var_data)
var_data.index = data.index
var_data  # finally drop the CPI 


# fill the missing value 
imputer = SimpleImputer(missing_values= np.NaN , strategy= 'mean')
var_data = imputer.fit_transform(var_data)
var_data = pd.DataFrame(var_data)
var_data.index = data.index
var_data

# pca 
pca = PCA(n_components=0.9)  # 一般 n_components 为0.9-0.95 左右
pca_data = pca.fit_transform(var_data)
pca_data = pd.DataFrame(pca_data)
pca_data.index = data.index 
pca_data
# Out:
#                     0          1
# trade_date
# 2015/1/2   -12.990441  14.978185
# 2015/1/5   -13.581706  15.822643
# 2015/1/6   -13.758934  15.533167
# 2015/1/7   -10.853545  14.182358
# 2015/1/8    -8.455334  12.443488
# ...               ...        ...
# 2020/11/19  81.884874  -0.776754
# 2020/11/20  80.620428  -0.201755
# 2020/11/23  80.640969   0.184254
# 2020/11/24  80.897901  -1.346451
# 2020/11/25  81.665735  -0.345307
#
# [1485 rows x 2 columns]

# %%
pca_data.to_csv('C.csv')
