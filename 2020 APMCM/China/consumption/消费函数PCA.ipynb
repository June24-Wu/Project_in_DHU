# %%
import tushare as ts
import pandas as pd 
import numpy as np

# %%
data = pd.read_csv('消费者股指.csv')
data.set_index('trade_date',inplace=True)
data
# Out:
#             601933.SH  600887.SH  600827.SH  600779.SH  600616.SH  600519.SH  \
# trade_date
# 2015/1/5         9.11      29.76      18.16      10.21       9.57     202.52
# 2015/1/6         9.09      29.88      18.21      10.09       9.60     197.83
# 2015/1/7         9.05      28.97      18.68      10.29       9.72     192.94
# 2015/1/8         8.92      28.64      17.99      10.49       9.57     191.76
# 2015/1/9         8.69      28.15      17.29      10.64       9.57     190.31
# ...               ...        ...        ...        ...        ...        ...
# 2020/11/20       7.87      39.23      13.99      74.75       6.81    1719.96
# 2020/11/23       7.84      39.51      13.78      75.09       7.49    1790.21
# 2020/11/24       7.81      38.70      13.70      74.10       8.20    1763.50
# 2020/11/25       7.79      37.79      13.07      70.88       7.38    1726.88
# 2020/11/26       7.74      38.12      13.50      71.65       7.02    1734.39
#
#             600300.SH  600251.SH  600132.SH  002714.SZ  002385.SZ  002304.SZ  \
# trade_date
# 2015/1/5         5.24      18.57      16.50      44.10      13.78      86.96
# 2015/1/6         5.30      18.68      16.58      47.64      14.10      86.95
# 2015/1/7         5.26      18.62      16.67      50.02      13.86      84.90
# 2015/1/8         5.30      18.64      16.58      52.00      13.97      84.62
# 2015/1/9         5.39      18.30      16.68      53.01      13.87      82.65
# ...               ...        ...        ...        ...        ...        ...
# 2020/11/20       4.28       7.20     108.30      72.97       8.13     177.90
# 2020/11/23       4.26       7.25     109.23      72.00       8.19     174.07
# 2020/11/24       4.09       7.25     113.20      72.42       8.16     186.46
# 2020/11/25       3.94       7.03     109.39      72.58       8.02     175.59
# 2020/11/26       3.87       7.06     108.22      75.00       7.99     176.25
#
#             000895.SZ  000876.SZ  000858.SZ  000568.SZ    CPI  Confidence Rate
# trade_date
# 2015/1/5        32.72      14.60      23.65      21.90  100.8            105.7
# 2015/1/6        33.97      14.73      23.76      21.58  100.8            105.7
# 2015/1/7        34.14      14.65      23.48      21.59  100.8            105.7
# 2015/1/8        33.64      14.81      23.93      21.64  100.8            105.7
# 2015/1/9        32.88      14.60      23.72      21.42  100.8            105.7
# ...               ...        ...        ...        ...    ...              ...
# 2020/11/20      51.32      26.09     268.47     194.15    NaN              NaN
# 2020/11/23      49.79      25.71     272.58     197.86    NaN              NaN
# 2020/11/24      50.09      25.78     271.79     198.77    NaN              NaN
# 2020/11/25      48.09      24.95     262.97     192.25    NaN              NaN
# 2020/11/26      47.69      24.88     260.58     192.75    NaN              NaN
#
# [1437 rows x 18 columns]

# %%
from sklearn.feature_selection import VarianceThreshold  # sklearn 方差过滤API
from sklearn.decomposition import PCA  # 主成分分析
from sklearn.impute import SimpleImputer # 处理缺失值


var = VarianceThreshold(threshold=1)  # threshold 是门槛
var_data = var.fit_transform(data)
var_data = pd.DataFrame(var_data)
var_data.index = data.index
var_data  # finally drop the CPI 


# fill the missing value 
imputer = SimpleImputer(missing_values= np.NaN , strategy= 'mean')
var_data = imputer.fit_transform(var_data)
var_data = pd.DataFrame(var_data)
var_data.index = data.index
var_data

# pca 
pca = PCA(n_components=0.9)  # 一般 n_components 为0.9-0.95 左右
pca_data = pca.fit_transform(var_data)
pca_data = pd.DataFrame(pca_data)
pca_data.index = data.index 
pca_data
# Out:
#                       0
# trade_date
# 2015/1/5    -464.579858
# 2015/1/6    -469.069098
# 2015/1/7    -473.931087
# 2015/1/8    -474.982208
# 2015/1/9    -476.512447
# ...                 ...
# 2020/11/20  1086.318199
# 2020/11/23  1156.190067
# 2020/11/24  1130.510601
# 2020/11/25  1092.045815
# 2020/11/26  1099.295523
#
# [1437 rows x 1 columns]

# %%
pca_data.to_csv('C.csv')
