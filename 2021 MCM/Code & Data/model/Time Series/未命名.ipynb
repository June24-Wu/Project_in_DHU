# %%
import pandas as pd 
data = pd.read_csv('Year.csv')
data = data[data.Year > 0 ]
data
# Out:
#                               Country          Year  Confidence
# 2                             Algeria     28.851502      0.0274
# 3                              Angola     13.799217      0.0640
# 8                             Austria    883.333333      0.0054
# 14                            Belarus    667.763158      0.0160
# 15                            Belgium     65.771060      0.0182
# 17                              Benin     15.947763      0.0684
# 22                             Brazil    266.165413      0.0457
# 24                           Bulgaria     48.779762      0.0069
# 25                       Burkina Faso    517.961538      0.0630
# 28                           Cambodia     59.879636      0.0676
# 33                              Chile    120.208768      0.0864
# 35                           Colombia     99.100069      0.1227
# 39                         Costa Rica    493.089172      0.0175
# 41                               Cuba     73.919510      0.0711
# ...

# %%
data.describe().to_csv('describe2.csv')
