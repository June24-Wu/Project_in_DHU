# %%
import pandas as pd  
import numpy as np
import matplotlib.pyplot as plt  
import seaborn as sns
df = pd.read_excel('topsis_new.xlsx')
df.set_index(['Country','Year'],inplace=True)
# df.drop('Food price inflation',axis=1,inplace=True)
df
# Out:
#                                          Production(hg)  Displacement Number  \
# Country                            Year
# Afghanistan                        2000    3.351530e+11                 3400
# Albania                            2000    6.074592e+10                  150
# Algeria                            2000    2.280440e+11                25000
# Angola                             2000    1.888670e+11                86000
# Antigua and Barbuda                2000    3.318306e+08                   45
# ...                                                 ...                  ...
# Venezuela (Bolivarian Republic of) 2019    4.121390e+11                10000
# Viet Nam                           2019    2.753240e+12                96200
# Yemen                              2019    1.156550e+11                10000
# Zambia                             2019    4.915340e+11                 1400
# Zimbabwe                           2019    2.989010e+11               104000
#
#                                          CH4 Emissions  CO2 Emissions   \
# Country                            Year
# Afghanistan                        2000       0.144000         33.3288
# Albania                            2000       0.139200       2485.3140
# Algeria                            2000       0.000000          0.0000
# Angola                             2000       0.002400         38.2356
# Antigua and Barbuda                2000       1.745104      21232.2405
# ...                                                ...             ...
# Venezuela (Bolivarian Republic of) 2019       0.292800       5238.2772
# Viet Nam                           2019       0.646800      11547.1512
# Yemen                              2019       0.085200       1529.4240
# Zambia                             2019       0.046800        841.1832
# Zimbabwe                           2019       0.193200       3441.2040
#
#                                          Per capita arable land
# Country                            Year
# Afghanistan                        2000                0.380000
# Albania                            2000                0.250625
# Algeria                            2000                0.250625
# Angola                             2000                0.250625
# Antigua and Barbuda                2000                0.250625
# ...                                                         ...
# Venezuela (Bolivarian Republic of) 2019                0.219000
# Viet Nam                           2019                0.219000
# Yemen                              2019                0.219000
# Zambia                             2019                0.219000
# Zimbabwe                           2019                0.290000
#
# [3760 rows x 5 columns]

# %%
df0 = df.corr()
df0
# Out:
#                         Production(hg)  Displacement Number  CH4 Emissions  \
# Production(hg)                1.000000             0.522471       0.375183
# Displacement Number           0.522471             1.000000       0.201044
# CH4 Emissions                 0.375183             0.201044       1.000000
# CO2 Emissions                 0.818273             0.415264       0.511070
# Per capita arable land        0.130329            -0.075394       0.079115
#
#                         CO2 Emissions   Per capita arable land
# Production(hg)                0.818273                0.130329
# Displacement Number           0.415264               -0.075394
# CH4 Emissions                 0.511070                0.079115
# CO2 Emissions                 1.000000                0.155875
# Per capita arable land        0.155875                1.000000

# %%
sns.heatmap(df.corr(), annot=True,cmap='YlGnBu')
# Out:
# <AxesSubplot:>
