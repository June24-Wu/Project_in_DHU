# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display
from warnings import filterwarnings
filterwarnings('ignore')
data = pd.read_excel('regression2.xlsx')
year_list = data['Year'].unique().tolist()
country_list = data['Country'].unique().tolist()
data.set_index(['Country','Year'],inplace=True)
# score = pd.read_csv('topsis_original.csv')
# score.set_index(['Country','Year'],inplace=True)
# score = pd.DataFrame(score['Score'])
# data = pd.concat([data,score],axis=1)
data
# Out:
#                                          Total Energy  Fertilizer  \
# Country                            Year
# Afghanistan                        2000    74174.8829        0.64
# Albania                            2000    77392.1087       26.75
# Algeria                            2000    74132.7500       11.27
# Angola                             2000    74182.8939        0.42
# Antigua and Barbuda                2000   100294.5043        0.00
# ...                                               ...         ...
# Venezuela (Bolivarian Republic of) 2019    81002.4751      139.67
# Viet Nam                           2019    89276.2317      251.76
# Yemen                              2019    76138.5091        3.03
# Zambia                             2019    75235.9175       52.02
# Zimbabwe                           2019    78645.7082       37.41
#
#                                          Consumption in Agriculture  \
# Country                            Year
# Afghanistan                        2000                    432.0000
# Albania                            2000                  33540.0000
# Algeria                            2000                      0.0000
# Angola                             2000                    516.0000
# Antigua and Barbuda                2000                 282880.2545
# ...                                                             ...
# Venezuela (Bolivarian Republic of) 2019                  70692.0000
# Viet Nam                           2019                 155832.0000
# Yemen                              2019                  20640.0000
# Zambia                             2019                  11352.0000
# Zimbabwe                           2019                  46440.0000
#
#                                          Government_Management  \
# Country                            Year
# Afghanistan                        2000              -1.350000
# Albania                            2000              -0.560000
# Algeria                            2000              -1.060000
# Angola                             2000              -1.520000
# Antigua and Barbuda                2000               1.270000
# ...                                                        ...
# Venezuela (Bolivarian Republic of) 2019              -0.068282
# Viet Nam                           2019              -0.068282
# Yemen                              2019              -0.068282
# Zambia                             2019              -0.700000
# Zimbabwe                           2019              -1.510000
#
#                                          Law&Political Stability  \
# Country                            Year
# Afghanistan                        2000                -2.630000
# Albania                            2000                -1.030000
# Algeria                            2000                -0.920000
# Angola                             2000                -1.180000
# Antigua and Barbuda                2000                -2.050000
# ...                                                          ...
# Venezuela (Bolivarian Republic of) 2019                 0.245215
# Viet Nam                           2019                 0.245215
# Yemen                              2019                 0.245215
# Zambia                             2019                 0.490000
# Zimbabwe                           2019                 0.410000
#
#                                          Unemployment_rate  Yield(hg/ha)  \
# Country                            Year
# Afghanistan                        2000          11.517000   57031.55319
# Albania                            2000          16.573000   93010.24194
# Algeria                            2000          29.770000   55748.24286
# Angola                             2000           3.837000   45371.66667
# Antigua and Barbuda                2000           8.394268   50049.87097
# ...                                                    ...           ...
# Venezuela (Bolivarian Republic of) 2019           6.896713  127383.85510
# Viet Nam                           2019           6.896713  101925.65380
# Yemen                              2019           6.896713   63858.63077
# Zambia                             2019          11.425000   98222.17949
# Zimbabwe                           2019           4.954000   59913.22892
#
#                                          Gini_Index           CPI  \
# Country                            Year
# Afghanistan                        2000   29.000000  3.951382e+01
# Albania                            2000   31.740000  6.660077e+01
# Algeria                            2000   27.620000  5.542482e+01
# Angola                             2000   51.960000  1.812510e+00
# Antigua and Barbuda                2000   39.583658  7.349858e+01
# ...                                             ...           ...
# Venezuela (Bolivarian Republic of) 2019   37.791460  2.633984e+08
# Viet Nam                           2019   37.791460  1.131217e+02
# Yemen                              2019   36.710000  1.844438e+02
# Zambia                             2019   57.140000  1.476608e+02
# Zimbabwe                           2019   40.362500  3.893035e+02
#
#                                          Male/Female  Rural/Urban  Developed  \
# Country                            Year
# Afghanistan                        2000     1.059369     3.529414          2
# Albania                            2000     1.024432     1.395734          1
# Algeria                            2000     1.027428     0.668931          1
# Angola                             2000     0.989632     0.996512          2
# Antigua and Barbuda                2000     0.886170     2.112650          1
# ...                                              ...          ...        ...
# Venezuela (Bolivarian Republic of) 2019     0.970604     0.133276          1
# Viet Nam                           2019     0.996700     1.730120          1
# Yemen                              2019     1.015387     1.682885          2
# Zambia                             2019     0.980638     1.269019          2
# Zimbabwe                           2019     0.911413     2.104625          1
#
#                                          Renewable energy consumption  \
# Country                            Year
# Afghanistan                        2000                     11301.390
# Albania                            2000                     25572.200
# Algeria                            2000                      2383.824
# Angola                             2000                    167766.400
# Antigua and Barbuda                2000                         0.000
# ...                                                               ...
# Venezuela (Bolivarian Republic of) 2019                           NaN
# Viet Nam                           2019                           NaN
# Yemen                              2019                           NaN
# Zambia                             2019                           NaN
# Zimbabwe                           2019                           NaN
#
#                                          Death under 5     Score
# Country                            Year
# Afghanistan                        2000       125079.0  4.057341
# Albania                            2000         1448.0  3.658972
# Algeria                            2000        24415.0  3.405881
# Angola                             2000       152254.0  2.791749
# Antigua and Barbuda                2000           23.0  2.937933
# ...                                                ...       ...
# Venezuela (Bolivarian Republic of) 2019            NaN  3.302967
# Viet Nam                           2019            NaN  3.093148
# Yemen                              2019            NaN  3.290519
# Zambia                             2019        38460.0  3.611598
# Zimbabwe                           2019        24166.0  3.021611
#
# [3760 rows x 15 columns]

# %%
one = data.drop('CPI',axis=1)
one = data.drop('CPI',axis=1)
one.corr()
# Out:
#                             Total Energy  Fertilizer  \
# Total Energy                    1.000000    0.247996
# Fertilizer                      0.247996    1.000000
# Consumption in Agriculture      0.996363    0.251846
# Government_Management           0.084341    0.346368
# Law&Political Stability         0.169348    0.271210
# Unemployment_rate              -0.067502   -0.031550
# Yield(hg/ha)                    0.041334    0.260312
# Gini_Index                      0.018395   -0.090209
# Male/Female                    -0.053296    0.158259
# Rural/Urban                    -0.135134   -0.308041
# Developed                      -0.147486   -0.347088
# Score                          -0.454346   -0.214158
#
#                             Consumption in Agriculture  Government_Management  \
# Total Energy                                  0.996363               0.084341
# Fertilizer                                    0.251846               0.346368
# Consumption in Agriculture                    1.000000               0.076679
# Government_Management                         0.076679               1.000000
# Law&Political Stability                       0.160590               0.187210
# Unemployment_rate                            -0.059368               0.037215
# Yield(hg/ha)                                  0.039311               0.419690
# Gini_Index                                    0.014446              -0.237967
# Male/Female                                  -0.051894               0.049977
# Rural/Urban                                  -0.130296              -0.370920
# Developed                                    -0.140427              -0.629567
# Score                                        -0.449498               0.124629
#
#                             Law&Political Stability  Unemployment_rate  \
# Total Energy                               0.169348          -0.067502
# Fertilizer                                 0.271210          -0.031550
# Consumption in Agriculture                 0.160590          -0.059368
# Government_Management                      0.187210           0.037215
# Law&Political Stability                    1.000000           0.023073
# Unemployment_rate                          0.023073           1.000000
# Yield(hg/ha)                               0.232672          -0.076807
# Gini_Index                                 0.081757           0.067457
# Male/Female                               -0.039514          -0.184002
# Rural/Urban                               -0.239810          -0.192760
# Developed                                 -0.352568          -0.093126
# Score                                      0.001894           0.137169
#
#                             Yield(hg/ha)  Gini_Index  Male/Female  \
# Total Energy                    0.041334    0.018395    -0.053296
# Fertilizer                      0.260312   -0.090209     0.158259
# Consumption in Agriculture      0.039311    0.014446    -0.051894
# Government_Management           0.419690   -0.237967     0.049977
# Law&Political Stability         0.232672    0.081757    -0.039514
# Unemployment_rate              -0.076807    0.067457    -0.184002
# Yield(hg/ha)                    1.000000   -0.183054     0.066275
# Gini_Index                     -0.183054    1.000000    -0.004045
# Male/Female                     0.066275   -0.004045     1.000000
# Rural/Urban                    -0.244056    0.112451    -0.101122
# Developed                      -0.406457    0.289653    -0.025485
# Score                           0.042464   -0.024491    -0.101191
#
#                             Rural/Urban  Developed     Score
# Total Energy                  -0.135134  -0.147486 -0.454346
# Fertilizer                    -0.308041  -0.347088 -0.214158
# Consumption in Agriculture    -0.130296  -0.140427 -0.449498
# Government_Management         -0.370920  -0.629567  0.124629
# Law&Political Stability       -0.239810  -0.352568  0.001894
# Unemployment_rate             -0.192760  -0.093126  0.137169
# Yield(hg/ha)                  -0.244056  -0.406457  0.042464
# Gini_Index                     0.112451   0.289653 -0.024491
# Male/Female                   -0.101122  -0.025485 -0.101191
# Rural/Urban                    1.000000   0.500987  0.002520
# Developed                      0.500987   1.000000 -0.098725
# Score                          0.002520  -0.098725  1.000000

# %%
# 归一化
X = data.drop(['Score','CPI','Consumption in Agriculture','Renewable energy consumption'],axis=1)
# X = data.drop(['Score'],axis=1)
Y = data['Score']
# from sklearn.preprocessing import MinMaxScaler
# scaler = MinMaxScaler(feature_range=(0, 1))  
# scaled_data = scaler.fit_transform(X)
# X = pd.DataFrame(scaled_data,index=X.index,columns=X.columns)
# print('X_Sclaer.shape: ',X.shape)
# data = pd.concat([X,Y],axis=1)
# data

# %%
sns.heatmap(X.corr(), annot=True,cmap='YlGnBu')
display(Y)
display(X)
# Out:
# Country                             Year
# Afghanistan                         2000    4.057341
# Albania                             2000    3.658972
# Algeria                             2000    3.405881
# Angola                              2000    2.791749
# Antigua and Barbuda                 2000    2.937933
#                                               ...
# Venezuela (Bolivarian Republic of)  2019    3.302967
# Viet Nam                            2019    3.093148
# Yemen                               2019    3.290519
# Zambia                              2019    3.611598
# Zimbabwe                            2019    3.021611
# Name: Score, Length: 3760, dtype: float64
#                                          Total Energy  Fertilizer  \
# Country                            Year
# Afghanistan                        2000    74174.8829        0.64
# Albania                            2000    77392.1087       26.75
# Algeria                            2000    74132.7500       11.27
# Angola                             2000    74182.8939        0.42
# Antigua and Barbuda                2000   100294.5043        0.00
# ...                                               ...         ...
# Venezuela (Bolivarian Republic of) 2019    81002.4751      139.67
# Viet Nam                           2019    89276.2317      251.76
# Yemen                              2019    76138.5091        3.03
# Zambia                             2019    75235.9175       52.02
# Zimbabwe                           2019    78645.7082       37.41
#
#                                          Government_Management  \
# Country                            Year
# Afghanistan                        2000              -1.350000
# Albania                            2000              -0.560000
# Algeria                            2000              -1.060000
# Angola                             2000              -1.520000
# Antigua and Barbuda                2000               1.270000
# ...                                                        ...
# Venezuela (Bolivarian Republic of) 2019              -0.068282
# Viet Nam                           2019              -0.068282
# Yemen                              2019              -0.068282
# Zambia                             2019              -0.700000
# Zimbabwe                           2019              -1.510000
#
#                                          Law&Political Stability  \
# Country                            Year
# Afghanistan                        2000                -2.630000
# Albania                            2000                -1.030000
# Algeria                            2000                -0.920000
# Angola                             2000                -1.180000
# Antigua and Barbuda                2000                -2.050000
# ...                                                          ...
# Venezuela (Bolivarian Republic of) 2019                 0.245215
# Viet Nam                           2019                 0.245215
# Yemen                              2019                 0.245215
# Zambia                             2019                 0.490000
# Zimbabwe                           2019                 0.410000
#
#                                          Unemployment_rate  Yield(hg/ha)  \
# Country                            Year
# Afghanistan                        2000          11.517000   57031.55319
# Albania                            2000          16.573000   93010.24194
# Algeria                            2000          29.770000   55748.24286
# Angola                             2000           3.837000   45371.66667
# Antigua and Barbuda                2000           8.394268   50049.87097
# ...                                                    ...           ...
# Venezuela (Bolivarian Republic of) 2019           6.896713  127383.85510
# Viet Nam                           2019           6.896713  101925.65380
# Yemen                              2019           6.896713   63858.63077
# Zambia                             2019          11.425000   98222.17949
# Zimbabwe                           2019           4.954000   59913.22892
#
#                                          Gini_Index  Male/Female  Rural/Urban  \
# Country                            Year
# Afghanistan                        2000   29.000000     1.059369     3.529414
# Albania                            2000   31.740000     1.024432     1.395734
# Algeria                            2000   27.620000     1.027428     0.668931
# Angola                             2000   51.960000     0.989632     0.996512
# Antigua and Barbuda                2000   39.583658     0.886170     2.112650
# ...                                             ...          ...          ...
# Venezuela (Bolivarian Republic of) 2019   37.791460     0.970604     0.133276
# Viet Nam                           2019   37.791460     0.996700     1.730120
# Yemen                              2019   36.710000     1.015387     1.682885
# Zambia                             2019   57.140000     0.980638     1.269019
# Zimbabwe                           2019   40.362500     0.911413     2.104625
#
#                                          Developed  Death under 5
# Country                            Year
# Afghanistan                        2000          2       125079.0
# Albania                            2000          1         1448.0
# Algeria                            2000          1        24415.0
# Angola                             2000          2       152254.0
# Antigua and Barbuda                2000          1           23.0
# ...                                            ...            ...
# Venezuela (Bolivarian Republic of) 2019          1            NaN
# Viet Nam                           2019          1            NaN
# Yemen                              2019          2            NaN
# Zambia                             2019          2        38460.0
# Zimbabwe                           2019          1        24166.0
#
# [3760 rows x 11 columns]

# %%
from xgboost import XGBRegressor as XGBR
from sklearn.ensemble import RandomForestRegressor as RFR
from sklearn.linear_model import LinearRegression as LinearR
from sklearn.datasets import load_boston
from sklearn.model_selection import KFold, cross_val_score as CVS, train_test_split as TTS
from sklearn.metrics import mean_squared_error as MSE
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from time import time
import datetime

rfr = RFR(
#             n_estimators=400
#             ,n_jobs=2,max_depth=16
#             ,max_features=2
#             ,min_samples_split=7
#             ,min_samples_leaf = 1 
#             ,random_state=420
        ) 
reg = XGBR(n_estimators=100)

# %%
from sklearn.model_selection import train_test_split

Xtrain,Xtest,Ytrain,Ytest= train_test_split(X,Y,
                                                test_size=0.2,
                                                random_state=420)
Xtrain.shape
# Out:
# (3008, 11)

# %%
model = reg.fit(X,Y)
print('Weight:   ' ,model.feature_importances_)
# Out:
# Weight:    [0.08151191 0.02523192 0.5446963  0.04178716 0.01030959 0.03133176
#  0.02761481 0.0336345  0.04920939 0.04601522 0.10865752]

# %%
CVS(reg,X,Y,cv=5).mean()#0.7975497480638329
# Out:
# 0.8270466216412334

# %%
def plot_learning_curve(estimator,title, X, y, 
                        ax=None, #选择子图
                        ylim=None, #设置纵坐标的取值范围
                        cv=None, #交叉验证
                        n_jobs=None #设定索要使用的线程
                       ):
    
    from sklearn.model_selection import learning_curve
    import matplotlib.pyplot as plt
    import numpy as np
    
    train_sizes, train_scores, test_scores = learning_curve(estimator, X, y
                                                            ,shuffle=True
                                                            ,cv=cv
                                                            ,random_state=420
                                                            ,n_jobs=n_jobs)      
    if ax == None:
        ax = plt.gca()
    else:
        ax = plt.figure()
    ax.set_title(title)
    if ylim is not None:
        ax.set_ylim(*ylim)
    ax.set_xlabel("Training examples")
    ax.set_ylabel("Score")
    ax.grid() #绘制网格，不是必须
    ax.plot(train_sizes, np.mean(train_scores, axis=1), 'o-'
            , color="r",label="Training score")
    ax.plot(train_sizes, np.mean(test_scores, axis=1), 'o-'
            , color="g",label="Test score")
    ax.legend(loc="best")
    return ax
cv = KFold(n_splits=5, shuffle = True, random_state=42) #交叉验证模式

# %%
plot_learning_curve(reg
                    ,"XGB",X,Y,ax=None,cv=cv)
plt.show()

# %%
#======【TIME WARNING: 20s】=======#
axisx = range(50,600,50)
rs = []
var = []
ge = []
for i in axisx:
    reg = XGBR(n_estimators=i,
#                max_depth = 8 ,
#                subsample=i ,
               random_state=420)
    cvresult = CVS(reg,X,Y,cv=cv)
    #记录1-偏差
    rs.append(cvresult.mean())
    #记录方差
    var.append(cvresult.var())
    #计算泛化误差的可控部分
    ge.append((1 - cvresult.mean())**2+cvresult.var())
    print(i ,'   ' , cvresult.mean())
#打印R2最高所对应的参数取值，并打印这个参数下的方差
print(axisx[rs.index(max(rs))],max(rs),var[rs.index(max(rs))])
#打印方差最低时对应的参数取值，并打印这个参数下的R2
print(axisx[var.index(min(var))],rs[var.index(min(var))],min(var))
#打印泛化误差可控部分的参数取值，并打印这个参数下的R2，方差以及泛化误差的可控部分
print(axisx[ge.index(min(ge))],rs[ge.index(min(ge))],var[ge.index(min(ge))],min(ge))
plt.figure(figsize=(20,5))
plt.plot(axisx,rs,c="red",label="XGB")
plt.legend()
plt.show()
# Out:
# 50     0.8878197515856534
# 100     0.8966288805146683
# 150     0.8987548847105945
# 200     0.8993804807042955
# 250     0.8996423142187961
# 300     0.899900682103017
# 350     0.9000926624858548
# 400     0.9001491152249959
# 450     0.9002219166603183
# 500     0.9002135655111472
# 550     0.9002168797775107
# 450 0.9002219166603183 0.00016185525895552377
# 150 0.8987548847105945 0.00015488041914523619
# 550 0.9002168797775107 0.00016002556487439715 0.01011669664621014

# %%
#======【TIME WARNING: 20s】=======#
axisx = range(1,10,2)
rs = []
var = []
ge = []
for i in axisx:
    reg = XGBR(n_estimators=450,
               max_depth = i,
#                subsample=i ,
               random_state=420)
    cvresult = CVS(reg,X,Y,cv=cv)
    #记录1-偏差
    rs.append(cvresult.mean())
    #记录方差
    var.append(cvresult.var())
    #计算泛化误差的可控部分
    ge.append((1 - cvresult.mean())**2+cvresult.var())
    print(i ,'   ' , cvresult.mean())
#打印R2最高所对应的参数取值，并打印这个参数下的方差
print(axisx[rs.index(max(rs))],max(rs),var[rs.index(max(rs))])
#打印方差最低时对应的参数取值，并打印这个参数下的R2
print(axisx[var.index(min(var))],rs[var.index(min(var))],min(var))
#打印泛化误差可控部分的参数取值，并打印这个参数下的R2，方差以及泛化误差的可控部分
print(axisx[ge.index(min(ge))],rs[ge.index(min(ge))],var[ge.index(min(ge))],min(ge))
plt.figure(figsize=(20,5))
plt.plot(axisx,rs,c="red",label="XGB")
plt.legend()
plt.show()
# Out:
# 1     0.5586502726807782
# 3     0.8733347747312378
# 5     0.8993792221934974
# 7     0.8992542375311207
# 9     0.899020608056279
# 5 0.8993792221934974 0.00011091184399728612
# 1 0.5586502726807782 7.635635137036019e-05
# 5 0.8993792221934974 0.00011091184399728612 0.01023545277038285

# %%
axisx = np.linspace(0,1,20)
rs = []
for i in axisx:
    reg = XGBR(n_estimators=450,subsample=i,random_state=420)
    rs.append(CVS(reg,X,Y,cv=cv).mean())
print(axisx[rs.index(max(rs))],max(rs))
plt.figure(figsize=(20,5))
plt.plot(axisx,rs,c="green",label="XGB")
plt.legend()
plt.show()
# Out:
# 0.894736842105263 0.9039736145728765

# %%
#首先我们先来定义一个评分函数，这个评分函数能够帮助我们直接打印Xtrain上的交叉验证结果
def regassess(reg,Xtrain,Ytrain,cv,scoring = ["r2"],show=True):
    score = []
    for i in range(len(scoring)):
        if show:
            print("{}:{:.2f}".format(scoring[i] #模型评估指标的名字
                                     ,CVS(reg
                                          ,Xtrain,Ytrain
                                          ,cv=cv,scoring=scoring[i]).mean()))
        score.append(CVS(reg,Xtrain,Ytrain,cv=cv,scoring=scoring[i]).mean())
    return score

# %%
reg = XGBR(n_estimators=460,
               random_state=420,
               subsample= 0.1)
regassess(reg,Xtrain,Ytrain,cv,scoring = ["r2","neg_mean_squared_error"])
# Out:
# r2:0.52
# neg_mean_squared_error:-0.22
# [0.5249795861993267, -0.22305663204290477]

# %%
axisx = np.arange(0.05,1,0.05)
rs = []
te = []
for i in axisx:
    reg = XGBR(n_estimators=450,
               random_state=420,
               subsample= 0.1 , 
               learning_rate=i)
    score = regassess(reg,Xtrain,Ytrain,cv,scoring = ["r2","neg_mean_squared_error"],show=False)
    test = reg.fit(Xtrain,Ytrain).score(Xtest,Ytest)
    rs.append(score[0])
    te.append(test)
print(axisx[rs.index(max(rs))],max(rs))
plt.figure(figsize=(20,5))
plt.plot(axisx,te,c="gray",label="test")
plt.plot(axisx,rs,c="green",label="train")
plt.legend()
plt.show()
# Out:
# 0.1 0.8626608693919939

# %%
import time
for booster in ["gbtree","gblinear","dart"]:
    time_start=time.time()


    reg = XGBR(n_estimators=460
               ,learning_rate=0.1
#                ,subsample= 0.2
               ,random_state=420
               ,booster=booster).fit(Xtrain,Ytrain)
    time_end=time.time()
    print('booster: ',booster)
    print('accuracy: ',reg.score(Xtest,Ytest))
    print('time cost',time_end-time_start,'s')
    print(' ')
    print('-----------------')
# Out:
# booster:  gbtree
# accuracy:  0.8990308429836704
# time cost 1.3316113948822021 s
#
# -----------------
# booster:  gblinear
# accuracy:  0.18958629029661977
# time cost 0.08178162574768066 s
#
# -----------------
# booster:  dart
# accuracy:  0.8988305410728527
# time cost 8.81508493423462 s
#
# -----------------

# %%
    reg = XGBR(n_estimators=450
               ,learning_rate=0.1
#                , max_depth = 8
#                ,subsample= 0.2
               ,random_state=420
               ,booster="gbtree")
plot_learning_curve(reg
                    ,"Boosting for New Model(delete some values2)",X,Y,ax=None,cv=cv)
plt.show()

# %%
print('Missing Value Number:')
num = X.isna().sum()
num
# Out:
# Missing Value Number:
# Total Energy                       0
# Fertilizer                         0
# Government_Management              0
# Law&Political Stability            0
# Unemployment_rate                  0
# Yield(hg/ha)                       0
# Gini_Index                         0
# Male/Female                        0
# Rural/Urban                        0
# Developed                          0
# Renewable energy consumption    1200
# dtype: int64

# %%
model = reg.fit(Xtrain,Ytrain)
print ('MSE:   ' , MSE(Ytest,model.predict(Xtest)))
model = reg.fit(X,Y)
print('Weight:   ' ,model.feature_importances_)
weight = pd.DataFrame(model.feature_importances_)
weight.index = X.columns
weight = weight.T
# weight.to_csv('r_weight.csv')
weight
# Out:
# MSE:    0.0391962810828856
# Weight:    [0.21840437 0.0497058  0.06828886 0.01336677 0.05167703 0.04543244
#  0.05740357 0.08861347 0.09380554 0.24018444 0.07311776]
#    Total Energy  Fertilizer  Government_Management  Law&Political Stability  \
# 0      0.218404    0.049706               0.068289                 0.013367
#
#    Unemployment_rate  Yield(hg/ha)  Gini_Index  Male/Female  Rural/Urban  \
# 0           0.051677      0.045432    0.057404     0.088613     0.093806
#
#    Developed  Death under 5
# 0   0.240184       0.073118

# %%
developed = data[data['Developed']==0]
developing = data[~(data['Developed']==0)]

developed_x = developed.drop(['Score','CPI','Developed','Consumption in Agriculture','Renewable energy consumption'],axis=1)
developed_y = developed['Score']

developing_x = developing.drop(['Score','CPI','Developed','Consumption in Agriculture','Renewable energy consumption'],axis=1)
developing_y = developing['Score']

developed_model = reg.fit(developed_x,developed_y)
print('Developed_Country_Weight:   ' ,developed_model.feature_importances_)
weight = pd.DataFrame(developed_model.feature_importances_,columns=['Developed'])
print('-------------------------------')
developing_model = reg.fit(developing_x,developing_y)
print('Developing_Country_Weight:   ' ,developing_model.feature_importances_)
weight['developing'] = pd.DataFrame(developing_model.feature_importances_)
weight.index = developed_x.columns
weight = weight.T
weight.to_csv('dev_weight.csv')
weight
# Out:
# Developed_Country_Weight:    [0.29674628 0.02958749 0.14084621 0.01697066 0.02107386 0.04967933
#  0.02185411 0.28200558 0.12436935 0.01686704]
# -------------------------------
# Developing_Country_Weight:    [0.29093003 0.0393087  0.08852675 0.02193191 0.07254507 0.05091885
#  0.06798024 0.11281501 0.13527809 0.11976536]
#             Total Energy  Fertilizer  Government_Management  \
# Developed       0.296746    0.029587               0.140846
# developing      0.290930    0.039309               0.088527
#
#             Law&Political Stability  Unemployment_rate  Yield(hg/ha)  \
# Developed                  0.016971           0.021074      0.049679
# developing                 0.021932           0.072545      0.050919
#
#             Gini_Index  Male/Female  Rural/Urban  Death under 5
# Developed     0.021854     0.282006     0.124369       0.016867
# developing    0.067980     0.112815     0.135278       0.119765

# %%
one = data.reset_index()

developed = one[one['Country']=='Finland']
developed = developed.drop(['Year','Country'],axis=1)
developed_x = developed.drop(['Score','CPI','Developed','Consumption in Agriculture','Death under 5','Total Energy'],axis=1)
developed_y = developed['Score']
developed_model = reg.fit(developed_x,developed_y)
print('Developed_Country_Weight:   ' ,developed_model.feature_importances_)
weight = pd.DataFrame(developed_model.feature_importances_,columns=['Developed'])
# Out:
# Developed_Country_Weight:    [0.03323117 0.5904088  0.09469775 0.05725574 0.15409842 0.02211084
#  0.03213225 0.         0.016065  ]

# %% [markdown]
# <!-- # import matplotlib.pyplot as plt -->
# fi = model.feature_importances_
# sorted_idx = np.argsort(fi)[-7:]
# pos = np.arange(sorted_idx.shape[0]) + .5
# fig, ax = plt.subplots()
# ax.barh(pos, fi[sorted_idx], align='center')
# plt.yticks(pos, np.array(X_test.columns)[sorted_idx])
# for i, v in enumerate(fi[sorted_idx].tolist()):
#     ax.text(v,i+.25,str(round(v*100,2))+'%',fontweight='bold')
# plt.show()
