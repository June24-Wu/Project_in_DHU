# %%
import pandas as pd  
import numpy as np
import matplotlib.pyplot as plt  
import seaborn as sns
df = pd.read_excel('topsis_original.xlsx')
df.set_index(['Area','Year'],inplace=True)
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-11c5652d0450> in <module>
#       3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
# ----> 5 df = pd.read_excel('topsis_original.xlsx')
#       6 df.set_index(['Area','Year'],inplace=True)
#       7 df.head()
#
# D:\ANACONDA\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# D:\ANACONDA\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols)
#     302
#     303     if not isinstance(io, ExcelFile):
# --> 304         io = ExcelFile(io, engine=engine)
#     305     elif engine and engine != io.engine:
#     306         raise ValueError(
#
# D:\ANACONDA\lib\site-packages\pandas\io\excel\_base.py in __init__(self, path_or_buffer, engine)
#     865         self._io = stringify_path(path_or_buffer)
#     866
# --> 867         self._reader = self._engines[engine](self._io)
#     868
#     869     def __fspath__(self):
#
# D:\ANACONDA\lib\site-packages\pandas\io\excel\_xlrd.py in __init__(self, filepath_or_buffer)
#      20         err_msg = "Install xlrd >= 1.0.0 for Excel support"
#      21         import_optional_dependency("xlrd", extra=err_msg)
# ---> 22         super().__init__(filepath_or_buffer)
#      23
#      24     @property
#
# D:\ANACONDA\lib\site-packages\pandas\io\excel\_base.py in __init__(self, filepath_or_buffer)
#     351             self.book = self.load_workbook(filepath_or_buffer)
#     352         elif isinstance(filepath_or_buffer, str):
# --> 353             self.book = self.load_workbook(filepath_or_buffer)
#     354         elif isinstance(filepath_or_buffer, bytes):
#     355             self.book = self.load_workbook(BytesIO(filepath_or_buffer))
#
# D:\ANACONDA\lib\site-packages\pandas\io\excel\_xlrd.py in load_workbook(self, filepath_or_buffer)
#      35             return open_workbook(file_contents=data)
#      36         else:
# ---> 37             return open_workbook(filepath_or_buffer)
#      38
#      39     @property
#
# D:\ANACONDA\lib\site-packages\xlrd\__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     109     else:
#     110         filename = os.path.expanduser(filename)
# --> 111         with open(filename, "rb") as f:
#     112             peek = f.read(peeksz)
#     113     if peek == b"PK\x03\x04": # a ZIP file
#
# FileNotFoundError: [Errno 2] No such file or directory: 'topsis_original.xlsx'

# %%
df0 = df.corr()
df0
# Out:
#                                                  Conflict and Disaster Stock Displacement Number  \
# Conflict and Disaster Stock Displacement Number                                         1.000000
# Producer Price Anuual Value                                                            -0.008795
# Total Population                                                                        0.679976
# Male/Female                                                                             0.005971
# Rural/Urban                                                                             0.015150
# \nPer capita arable land area                                                          -0.075394
# Consumption in Agriculture                                                              0.415509
# Emissions (CH4) (Energy)                                                                0.201044
# Emissions (CO2) (Energy)                                                                0.415264
# Emissions (CO2eq) (Energy)                                                              0.415337
# Emissions (CO2eq) from CH4 (Energy)                                                     0.201045
# Total Energy                                                                            0.384603
# Yield(hg/ha)                                                                           -0.030339
# Area harvested(ha)                                                                      0.572909
# Production(hg)                                                                          0.522471
# Export Value                                                                            0.302244
# Import Value                                                                            0.300823
# Net exports Value                                                                      -0.090212
# Gini_Index                                                                              0.019102
# Unemployment_rate                                                                      -0.068539
# Government_Management                                                                  -0.153721
# Law&Political Stability                                                                 0.056070
# Forest cover rate                                                                      -0.072292
# Consumer Prices, Food Indices (2015 = 100)                                             -0.002754
# Consumer Prices, General Indices (2015 = 100)                                          -0.002753
# Food price inflation                                                                   -0.003223
# Fertilizer                                                                              0.142914
#
#                                                  Producer Price Anuual Value  \
# Conflict and Disaster Stock Displacement Number                    -0.008795
# Producer Price Anuual Value                                         1.000000
# Total Population                                                   -0.034667
# Male/Female                                                         0.041834
# Rural/Urban                                                        -0.091443
# \nPer capita arable land area                                      -0.107635
# Consumption in Agriculture                                         -0.022671
# Emissions (CH4) (Energy)                                            0.019950
# Emissions (CO2) (Energy)                                           -0.021265
# Emissions (CO2eq) (Energy)                                         -0.021447
# Emissions (CO2eq) from CH4 (Energy)                                 0.019948
# Total Energy                                                       -0.022543
# Yield(hg/ha)                                                        0.110750
# Area harvested(ha)                                                 -0.049110
# Production(hg)                                                     -0.014613
# Export Value                                                        0.103118
# Import Value                                                        0.099200
# Net exports Value                                                  -0.015865
# Gini_Index                                                         -0.108727
# Unemployment_rate                                                  -0.041504
# Government_Management                                               0.084522
# Law&Political Stability                                             0.276188
# Forest cover rate                                                   0.015749
# Consumer Prices, Food Indices (2015 = 100)                         -0.043351
# Consumer Prices, General Indices (2015 = 100)                      -0.043324
# Food price inflation                                               -0.052754
# Fertilizer                                                          0.103812
#
#                                                  Total Population  \
# Conflict and Disaster Stock Displacement Number          0.679976
# Producer Price Anuual Value                             -0.034667
# Total Population                                         1.000000
# Male/Female                                              0.008233
# Rural/Urban                                              0.011540
# \nPer capita arable land area                           -0.064452
# Consumption in Agriculture                               0.637459
# Emissions (CH4) (Energy)                                 0.295368
# Emissions (CO2) (Energy)                                 0.636459
# Emissions (CO2eq) (Energy)                               0.636642
# Emissions (CO2eq) from CH4 (Energy)                      0.295367
# Total Energy                                             0.610959
# Yield(hg/ha)                                            -0.006187
# Area harvested(ha)                                       0.916169
# Production(hg)                                           0.850973
# Export Value                                             0.522690
# Import Value                                             0.526909
# Net exports Value                                       -0.185001
# Gini_Index                                               0.011689
# Unemployment_rate                                       -0.086137
# Government_Management                                   -0.071192
# Law&Political Stability                                  0.138414
# Forest cover rate                                       -0.038811
# Consumer Prices, Food Indices (2015 = 100)              -0.000194
# Consumer Prices, General Indices (2015 = 100)           -0.000194
# Food price inflation                                    -0.000253
# Fertilizer                                               0.233865
#
#                                                  Male/Female  Rural/Urban  \
# Conflict and Disaster Stock Displacement Number     0.005971     0.015150
# Producer Price Anuual Value                         0.041834    -0.091443
# Total Population                                    0.008233     0.011540
# Male/Female                                         1.000000    -0.101122
# Rural/Urban                                        -0.101122     1.000000
# \nPer capita arable land area                      -0.164048    -0.070935
# Consumption in Agriculture                         -0.051894    -0.130296
# Emissions (CH4) (Energy)                            0.161423    -0.124531
# Emissions (CO2) (Energy)                           -0.043432    -0.133046
# Emissions (CO2eq) (Energy)                         -0.044466    -0.132724
# Emissions (CO2eq) from CH4 (Energy)                 0.161423    -0.124529
# Total Energy                                       -0.053296    -0.135134
# Yield(hg/ha)                                        0.066275    -0.244056
# Area harvested(ha)                                 -0.021303    -0.015675
# Production(hg)                                     -0.019745    -0.060198
# Export Value                                        0.003171    -0.190438
# Import Value                                       -0.006509    -0.175093
# Net exports Value                                   0.041028    -0.005917
# Gini_Index                                         -0.004010     0.112781
# Unemployment_rate                                  -0.184002    -0.192760
# Government_Management                               0.049977    -0.370920
# Law&Political Stability                            -0.039514    -0.239810
# Forest cover rate                                  -0.186321    -0.010017
# Consumer Prices, Food Indices (2015 = 100)         -0.003639    -0.013622
# Consumer Prices, General Indices (2015 = 100)      -0.003637    -0.013614
# Food price inflation                               -0.005098    -0.015841
# Fertilizer                                          0.158259    -0.308041
#
#                                                  \nPer capita arable land area  \
# Conflict and Disaster Stock Displacement Number                      -0.075394
# Producer Price Anuual Value                                          -0.107635
# Total Population                                                     -0.064452
# Male/Female                                                          -0.164048
# Rural/Urban                                                          -0.070935
# \nPer capita arable land area                                         1.000000
# Consumption in Agriculture                                            0.155653
# Emissions (CH4) (Energy)                                              0.079115
# Emissions (CO2) (Energy)                                              0.155875
# Emissions (CO2eq) (Energy)                                            0.155890
# Emissions (CO2eq) from CH4 (Energy)                                   0.079116
# Total Energy                                                          0.167248
# Yield(hg/ha)                                                         -0.051971
# Area harvested(ha)                                                    0.115122
# Production(hg)                                                        0.130329
# Export Value                                                          0.057428
# Import Value                                                          0.040665
# Net exports Value                                                     0.054491
# Gini_Index                                                           -0.005059
# Unemployment_rate                                                     0.092101
# Government_Management                                                -0.003060
# Law&Political Stability                                               0.031102
# Forest cover rate                                                     0.076004
# Consumer Prices, Food Indices (2015 = 100)                           -0.000920
# Consumer Prices, General Indices (2015 = 100)                        -0.000919
# Food price inflation                                                 -0.000264
# Fertilizer                                                           -0.196794
#
#                                                  Consumption in Agriculture  \
# Conflict and Disaster Stock Displacement Number                    0.415509
# Producer Price Anuual Value                                       -0.022671
# Total Population                                                   0.637459
# Male/Female                                                       -0.051894
# Rural/Urban                                                       -0.130296
# \nPer capita arable land area                                      0.155653
# Consumption in Agriculture                                         1.000000
# Emissions (CH4) (Energy)                                           0.472131
# Emissions (CO2) (Energy)                                           0.998967
# Emissions (CO2eq) (Energy)                                         0.999191
# Emissions (CO2eq) from CH4 (Energy)                                0.472129
# Total Energy                                                       0.996363
# Yield(hg/ha)                                                       0.039311
# Area harvested(ha)                                                 0.708586
# Production(hg)                                                     0.819715
# Export Value                                                       0.733195
# Import Value                                                       0.750035
# Net exports Value                                                 -0.306941
# Gini_Index                                                         0.014246
# Unemployment_rate                                                 -0.059368
# Government_Management                                              0.076679
# Law&Political Stability                                            0.160590
# Forest cover rate                                                  0.022300
# Consumer Prices, Food Indices (2015 = 100)                        -0.004064
# Consumer Prices, General Indices (2015 = 100)                     -0.004061
# Food price inflation                                              -0.005304
# Fertilizer                                                         0.251846
#
#                                                  Emissions (CH4) (Energy)  \
# Conflict and Disaster Stock Displacement Number                  0.201044
# Producer Price Anuual Value                                      0.019950
# Total Population                                                 0.295368
# Male/Female                                                      0.161423
# Rural/Urban                                                     -0.124531
# \nPer capita arable land area                                    0.079115
# Consumption in Agriculture                                       0.472131
# Emissions (CH4) (Energy)                                         1.000000
# Emissions (CO2) (Energy)                                         0.511070
# Emissions (CO2eq) (Energy)                                       0.506601
# Emissions (CO2eq) from CH4 (Energy)                              1.000000
# Total Energy                                                     0.475583
# Yield(hg/ha)                                                     0.016395
# Area harvested(ha)                                               0.316387
# Production(hg)                                                   0.375183
# Export Value                                                     0.371014
# Import Value                                                     0.370943
# Net exports Value                                               -0.118004
# Gini_Index                                                       0.029573
# Unemployment_rate                                               -0.045276
# Government_Management                                           -0.059767
# Law&Political Stability                                          0.004348
# Forest cover rate                                               -0.150039
# Consumer Prices, Food Indices (2015 = 100)                      -0.003512
# Consumer Prices, General Indices (2015 = 100)                   -0.003510
# Food price inflation                                            -0.004651
# Fertilizer                                                       0.133495
#
#                                                  Emissions (CO2) (Energy)  \
# Conflict and Disaster Stock Displacement Number                  0.415264
# Producer Price Anuual Value                                     -0.021265
# Total Population                                                 0.636459
# Male/Female                                                     -0.043432
# Rural/Urban                                                     -0.133046
# \nPer capita arable land area                                    0.155875
# Consumption in Agriculture                                       0.998967
# Emissions (CH4) (Energy)                                         0.511070
# Emissions (CO2) (Energy)                                         1.000000
# Emissions (CO2eq) (Energy)                                       0.999986
# Emissions (CO2eq) from CH4 (Energy)                              0.511068
# Total Energy                                                     0.995607
# Yield(hg/ha)                                                     0.038942
# Area harvested(ha)                                               0.706949
# Production(hg)                                                   0.818273
# Export Value                                                     0.733486
# Import Value                                                     0.749949
# Net exports Value                                               -0.305397
# Gini_Index                                                       0.015176
# Unemployment_rate                                               -0.060065
# Government_Management                                            0.071637
# Law&Political Stability                                          0.156441
# Forest cover rate                                                0.014547
# Consumer Prices, Food Indices (2015 = 100)                      -0.004125
# Consumer Prices, General Indices (2015 = 100)                   -0.004122
# Food price inflation                                            -0.005388
# Fertilizer                                                       0.252427
#
#                                                  Emissions (CO2eq) (Energy)  \
# Conflict and Disaster Stock Displacement Number                    0.415337
# Producer Price Anuual Value                                       -0.021447
# Total Population                                                   0.636642
# Male/Female                                                       -0.044466
# Rural/Urban                                                       -0.132724
# \nPer capita arable land area                                      0.155890
# Consumption in Agriculture                                         0.999191
# Emissions (CH4) (Energy)                                           0.506601
# Emissions (CO2) (Energy)                                           0.999986
# Emissions (CO2eq) (Energy)                                         1.000000
# Emissions (CO2eq) from CH4 (Energy)                                0.506600
# Total Energy                                                       0.995799
# Yield(hg/ha)                                                       0.038959
# Area harvested(ha)                                                 0.707215
# Production(hg)                                                     0.818527
# Export Value                                                       0.733526
# Import Value                                                       0.750035
# Net exports Value                                                 -0.305611
# Gini_Index                                                         0.015073
# Unemployment_rate                                                 -0.059972
# Government_Management                                              0.072231
# Law&Political Stability                                            0.156939
# Forest cover rate                                                  0.015476
# Consumer Prices, Food Indices (2015 = 100)                        -0.004117
# Consumer Prices, General Indices (2015 = 100)                     -0.004115
# Food price inflation                                              -0.005378
# Fertilizer                                                         0.252385
#
#                                                  ...  Net exports Value  \
# Conflict and Disaster Stock Displacement Number  ...          -0.090212
# Producer Price Anuual Value                      ...          -0.015865
# Total Population                                 ...          -0.185001
# Male/Female                                      ...           0.041028
# Rural/Urban                                      ...          -0.005917
# \nPer capita arable land area                    ...           0.054491
# Consumption in Agriculture                       ...          -0.306941
# Emissions (CH4) (Energy)                         ...          -0.118004
# Emissions (CO2) (Energy)                         ...          -0.305397
# Emissions (CO2eq) (Energy)                       ...          -0.305611
# Emissions (CO2eq) from CH4 (Energy)              ...          -0.118005
# Total Energy                                     ...          -0.310874
# Yield(hg/ha)                                     ...           0.074552
# Area harvested(ha)                               ...          -0.188768
# Production(hg)                                   ...          -0.309094
# Export Value                                     ...          -0.207271
# Import Value                                     ...          -0.422306
# Net exports Value                                ...           1.000000
# Gini_Index                                       ...           0.008651
# Unemployment_rate                                ...          -0.000005
# Government_Management                            ...          -0.035464
# Law&Political Stability                          ...          -0.007245
# Forest cover rate                                ...          -0.001281
# Consumer Prices, Food Indices (2015 = 100)       ...          -0.002595
# Consumer Prices, General Indices (2015 = 100)    ...          -0.002592
# Food price inflation                             ...          -0.003745
# Fertilizer                                       ...          -0.088947
#
#                                                  Gini_Index  \
# Conflict and Disaster Stock Displacement Number    0.019102
# Producer Price Anuual Value                       -0.108727
# Total Population                                   0.011689
# Male/Female                                       -0.004010
# Rural/Urban                                        0.112781
# \nPer capita arable land area                     -0.005059
# Consumption in Agriculture                         0.014246
# Emissions (CH4) (Energy)                           0.029573
# Emissions (CO2) (Energy)                           0.015176
# Emissions (CO2eq) (Energy)                         0.015073
# Emissions (CO2eq) from CH4 (Energy)                0.029575
# Total Energy                                       0.018183
# Yield(hg/ha)                                      -0.183195
# Area harvested(ha)                                 0.032663
# Production(hg)                                     0.028889
# Export Value                                      -0.055492
# Import Value                                      -0.053410
# Net exports Value                                  0.008651
# Gini_Index                                         1.000000
# Unemployment_rate                                  0.067578
# Government_Management                             -0.238797
# Law&Political Stability                            0.081670
# Forest cover rate                                  0.127011
# Consumer Prices, Food Indices (2015 = 100)        -0.002575
# Consumer Prices, General Indices (2015 = 100)     -0.002574
# Food price inflation                              -0.002689
# Fertilizer                                        -0.090258
#
#                                                  Unemployment_rate  \
# Conflict and Disaster Stock Displacement Number          -0.068539
# Producer Price Anuual Value                              -0.041504
# Total Population                                         -0.086137
# Male/Female                                              -0.184002
# Rural/Urban                                              -0.192760
# \nPer capita arable land area                             0.092101
# Consumption in Agriculture                               -0.059368
# Emissions (CH4) (Energy)                                 -0.045276
# Emissions (CO2) (Energy)                                 -0.060065
# Emissions (CO2eq) (Energy)                               -0.059972
# Emissions (CO2eq) from CH4 (Energy)                      -0.045276
# Total Energy                                             -0.067502
# Yield(hg/ha)                                             -0.076807
# Area harvested(ha)                                       -0.087367
# Production(hg)                                           -0.070889
# Export Value                                             -0.066493
# Import Value                                             -0.061610
# Net exports Value                                        -0.000005
# Gini_Index                                                0.067578
# Unemployment_rate                                         1.000000
# Government_Management                                     0.037215
# Law&Political Stability                                   0.023073
# Forest cover rate                                        -0.028981
# Consumer Prices, Food Indices (2015 = 100)               -0.002699
# Consumer Prices, General Indices (2015 = 100)            -0.002697
# Food price inflation                                     -0.003927
# Fertilizer                                               -0.031550
#
#                                                  Government_Management  \
# Conflict and Disaster Stock Displacement Number              -0.153721
# Producer Price Anuual Value                                   0.084522
# Total Population                                             -0.071192
# Male/Female                                                   0.049977
# Rural/Urban                                                  -0.370920
# \nPer capita arable land area                                -0.003060
# Consumption in Agriculture                                    0.076679
# Emissions (CH4) (Energy)                                     -0.059767
# Emissions (CO2) (Energy)                                      0.071637
# Emissions (CO2eq) (Energy)                                    0.072231
# Emissions (CO2eq) from CH4 (Energy)                          -0.059770
# Total Energy                                                  0.084341
# Yield(hg/ha)                                                  0.419690
# Area harvested(ha)                                           -0.056918
# Production(hg)                                                0.026330
# Export Value                                                  0.248190
# Import Value                                                  0.238132
# Net exports Value                                            -0.035464
# Gini_Index                                                   -0.238797
# Unemployment_rate                                             0.037215
# Government_Management                                         1.000000
# Law&Political Stability                                       0.187210
# Forest cover rate                                             0.117979
# Consumer Prices, Food Indices (2015 = 100)                   -0.001059
# Consumer Prices, General Indices (2015 = 100)                -0.001058
# Food price inflation                                         -0.004197
# Fertilizer                                                    0.346368
#
#                                                  Law&Political Stability  \
# Conflict and Disaster Stock Displacement Number                 0.056070
# Producer Price Anuual Value                                     0.276188
# Total Population                                                0.138414
# Male/Female                                                    -0.039514
# Rural/Urban                                                    -0.239810
# \nPer capita arable land area                                   0.031102
# Consumption in Agriculture                                      0.160590
# Emissions (CH4) (Energy)                                        0.004348
# Emissions (CO2) (Energy)                                        0.156441
# Emissions (CO2eq) (Energy)                                      0.156939
# Emissions (CO2eq) from CH4 (Energy)                             0.004346
# Total Energy                                                    0.169348
# Yield(hg/ha)                                                    0.232672
# Area harvested(ha)                                              0.177520
# Production(hg)                                                  0.187807
# Export Value                                                    0.266314
# Import Value                                                    0.248428
# Net exports Value                                              -0.007245
# Gini_Index                                                      0.081670
# Unemployment_rate                                               0.023073
# Government_Management                                           0.187210
# Law&Political Stability                                         1.000000
# Forest cover rate                                              -0.011758
# Consumer Prices, Food Indices (2015 = 100)                      0.001532
# Consumer Prices, General Indices (2015 = 100)                   0.001531
# Food price inflation                                            0.001886
# Fertilizer                                                      0.271210
#
#                                                  Forest cover rate  \
# Conflict and Disaster Stock Displacement Number          -0.072292
# Producer Price Anuual Value                               0.015749
# Total Population                                         -0.038811
# Male/Female                                              -0.186321
# Rural/Urban                                              -0.010017
# \nPer capita arable land area                             0.076004
# Consumption in Agriculture                                0.022300
# Emissions (CH4) (Energy)                                 -0.150039
# Emissions (CO2) (Energy)                                  0.014547
# Emissions (CO2eq) (Energy)                                0.015476
# Emissions (CO2eq) from CH4 (Energy)                      -0.150039
# Total Energy                                              0.023645
# Yield(hg/ha)                                             -0.125292
# Area harvested(ha)                                       -0.027266
# Production(hg)                                           -0.012166
# Export Value                                             -0.001753
# Import Value                                             -0.001330
# Net exports Value                                        -0.001281
# Gini_Index                                                0.127011
# Unemployment_rate                                        -0.028981
# Government_Management                                     0.117979
# Law&Political Stability                                  -0.011758
# Forest cover rate                                         1.000000
# Consumer Prices, Food Indices (2015 = 100)               -0.000534
# Consumer Prices, General Indices (2015 = 100)            -0.000534
# Food price inflation                                     -0.000051
# Fertilizer                                                0.031295
#
#                                                  Consumer Prices, Food Indices (2015 = 100)  \
# Conflict and Disaster Stock Displacement Number                                   -0.002754
# Producer Price Anuual Value                                                       -0.043351
# Total Population                                                                  -0.000194
# Male/Female                                                                       -0.003639
# Rural/Urban                                                                       -0.013622
# \nPer capita arable land area                                                     -0.000920
# Consumption in Agriculture                                                        -0.004064
# Emissions (CH4) (Energy)                                                          -0.003512
# Emissions (CO2) (Energy)                                                          -0.004125
# Emissions (CO2eq) (Energy)                                                        -0.004117
# Emissions (CO2eq) from CH4 (Energy)                                               -0.003510
# Total Energy                                                                      -0.004164
# Yield(hg/ha)                                                                       0.001138
# Area harvested(ha)                                                                -0.003677
# Production(hg)                                                                    -0.002923
# Export Value                                                                      -0.005733
# Import Value                                                                      -0.004715
# Net exports Value                                                                 -0.002595
# Gini_Index                                                                        -0.002575
# Unemployment_rate                                                                 -0.002699
# Government_Management                                                             -0.001059
# Law&Political Stability                                                            0.001532
# Forest cover rate                                                                 -0.000534
# Consumer Prices, Food Indices (2015 = 100)                                         1.000000
# Consumer Prices, General Indices (2015 = 100)                                      1.000000
# Food price inflation                                                               0.966389
# Fertilizer                                                                         0.009560
#
#                                                  Consumer Prices, General Indices (2015 = 100)  \
# Conflict and Disaster Stock Displacement Number                                      -0.002753
# Producer Price Anuual Value                                                          -0.043324
# Total Population                                                                     -0.000194
# Male/Female                                                                          -0.003637
# Rural/Urban                                                                          -0.013614
# \nPer capita arable land area                                                        -0.000919
# Consumption in Agriculture                                                           -0.004061
# Emissions (CH4) (Energy)                                                             -0.003510
# Emissions (CO2) (Energy)                                                             -0.004122
# Emissions (CO2eq) (Energy)                                                           -0.004115
# Emissions (CO2eq) from CH4 (Energy)                                                  -0.003508
# Total Energy                                                                         -0.004161
# Yield(hg/ha)                                                                          0.001138
# Area harvested(ha)                                                                   -0.003674
# Production(hg)                                                                       -0.002921
# Export Value                                                                         -0.005730
# Import Value                                                                         -0.004712
# Net exports Value                                                                    -0.002592
# Gini_Index                                                                           -0.002574
# Unemployment_rate                                                                    -0.002697
# Government_Management                                                                -0.001058
# Law&Political Stability                                                               0.001531
# Forest cover rate                                                                    -0.000534
# Consumer Prices, Food Indices (2015 = 100)                                            1.000000
# Consumer Prices, General Indices (2015 = 100)                                         1.000000
# Food price inflation                                                                  0.966233
# Fertilizer                                                                            0.009554
#
#                                                  Food price inflation  \
# Conflict and Disaster Stock Displacement Number             -0.003223
# Producer Price Anuual Value                                 -0.052754
# Total Population                                            -0.000253
# Male/Female                                                 -0.005098
# Rural/Urban                                                 -0.015841
# \nPer capita arable land area                               -0.000264
# Consumption in Agriculture                                  -0.005304
# Emissions (CH4) (Energy)                                    -0.004651
# Emissions (CO2) (Energy)                                    -0.005388
# Emissions (CO2eq) (Energy)                                  -0.005378
# Emissions (CO2eq) from CH4 (Energy)                         -0.004649
# Total Energy                                                -0.005458
# Yield(hg/ha)                                                 0.000498
# Area harvested(ha)                                          -0.004500
# Production(hg)                                              -0.003769
# Export Value                                                -0.007631
# Import Value                                                -0.006209
# Net exports Value                                           -0.003745
# Gini_Index                                                  -0.002689
# Unemployment_rate                                           -0.003927
# Government_Management                                       -0.004197
# Law&Political Stability                                      0.001886
# Forest cover rate                                           -0.000051
# Consumer Prices, Food Indices (2015 = 100)                   0.966389
# Consumer Prices, General Indices (2015 = 100)                0.966233
# Food price inflation                                         1.000000
# Fertilizer                                                   0.010498
#
#                                                  Fertilizer
# Conflict and Disaster Stock Displacement Number    0.142914
# Producer Price Anuual Value                        0.103812
# Total Population                                   0.233865
# Male/Female                                        0.158259
# Rural/Urban                                       -0.308041
# \nPer capita arable land area                     -0.196794
# Consumption in Agriculture                         0.251846
# Emissions (CH4) (Energy)                           0.133495
# Emissions (CO2) (Energy)                           0.252427
# Emissions (CO2eq) (Energy)                         0.252385
# Emissions (CO2eq) from CH4 (Energy)                0.133492
# Total Energy                                       0.247996
# Yield(hg/ha)                                       0.260312
# Area harvested(ha)                                 0.150408
# Production(hg)                                     0.200764
# Export Value                                       0.332278
# Import Value                                       0.328361
# Net exports Value                                 -0.088947
# Gini_Index                                        -0.090258
# Unemployment_rate                                 -0.031550
# Government_Management                              0.346368
# Law&Political Stability                            0.271210
# Forest cover rate                                  0.031295
# Consumer Prices, Food Indices (2015 = 100)         0.009560
# Consumer Prices, General Indices (2015 = 100)      0.009554
# Food price inflation                               0.010498
# Fertilizer                                         1.000000
#
# [27 rows x 27 columns]

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>
